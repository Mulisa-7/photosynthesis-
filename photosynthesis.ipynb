# %%
import pandas as pd
import numpy as np

# %%
url='https://docs.google.com/spreadsheets/d/1NvykYfgkDoGhqkw_NvXhEYtO_o59JXQ2/edit#gid=14785455'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
df_leaf_measurement = pd.read_xlsx(url)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [4], in <cell line: 3>()
#       1 url='https://docs.google.com/spreadsheets/d/1NvykYfgkDoGhqkw_NvXhEYtO_o59JXQ2/edit#gid=14785455'
#       2 url='https://drive.google.com/uc?id=' + url.split('/')[-2]
# ----> 3 df_leaf_measurement = pd.read_xlsx(url)
#
# File /opt/homebrew/Cellar/jupyterlab/3.3.2/libexec/lib/python3.9/site-packages/pandas/__init__.py:261, in __getattr__(name)
#     257     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     259     return _SparseArray
# --> 261 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'read_xlsx'

# %%
file_data = 'leaf_measurements.xlsx'
directory = '/Users/yingyuepeng/Google drive/Shared drives/03_Projects/08_Cyprus/07_data/02_measurements_our_experiment/'
df = pd.read_excel(os.path.join(directory, file_data), header = 1)

# %%
import pandas as pd
import os

# %%
df
# Out:
#            Date  Plant_number  Width   Length  \
# 0    2021-12-14           1.0    29.0    45.0
# 1    2021-12-14           1.0    28.0    50.0
# 2    2021-12-14           1.0    23.0    46.0
# 3    2021-12-14           1.0    26.0    60.0
# 4    2021-12-14           1.0    34.0    54.0
# ...         ...           ...     ...     ...
# 1614 2022-05-24           5.0    28.0    30.0
# 1615 2022-05-24           5.0    22.0    31.0
# 1616 2022-05-24           5.0    15.0    25.0
# 1617 2022-05-24           5.0    14.0    22.0
# 1618 2022-05-24           5.0    13.0    18.0
#
#                                            Observations
# 0     Width was half, and we measured the rachid (in...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# ...

# %%
import sys

def get_base_prefix_compat():
    """Get base/real prefix, or sys.prefix if there is none."""
    return getattr(sys, "base_prefix", None) or getattr(sys, "real_prefix", None) or sys.prefix

def in_virtualenv():
    return get_base_prefix_compat() != sys.prefix

# %%
sys.prefix == sys.base_prefix
# Out:
# False

# %%
pip install openpyxl
